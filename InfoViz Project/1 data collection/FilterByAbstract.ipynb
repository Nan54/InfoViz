# %% [markdown]
# # Filtering papers by abstract contents
#
# With the abstracts in hand, we can start looking for keywords that pertain to AI ethics, algorithmic fairness, data privacy, and other topics. To do this, we have made 3 lists of keywords across different topics. If at least one word from each list is present in the abstract, that paper will pass through the filter. To generate these keyword lists, we performed TF-IDF analysis on the focused dataset, and created 3-person consensus on whether to keep or remove certain words which had the 100 highest median scores across the corpus. Afterwards, we will use the same keyword lists as a filter on the full dataset containing all the abstracts saved in MAG.

# %%
import pandas as pd
import numpy as np

# %%
def listAFilter(df):
    al = np.array_split(df, 50)
    i = 1
    res = pd.DataFrame()
    for a in al:
        a['Indexed Abstract'] = a['Indexed Abstract'].apply(str.lower)
        a['A'] = a['Indexed Abstract'].str.contains('|'.join(keyA))
        res = pd.concat([res, a])
        if i % 10 == 0:
            print('list ' + str(i) + ' checked')
    return res

def listBFilter(df):
    al = np.array_split(df, 50)
    i = 1
    res = pd.DataFrame()
    for a in al:
        a['B'] = a['Indexed Abstract'].str.contains('|'.join(keyB))
        res = pd.concat([res, a])
        if i % 10 == 0:
            print('list ' + str(i) + ' checked')
    return res

def listCFilter(df):
    al = np.array_split(df, 50)
    i = 1
    res = pd.DataFrame()
    for a in al:
        a['C'] = a['Indexed Abstract'].str.contains('|'.join(keyC))
        res = pd.concat([res, a])
        if i % 10 == 0:
            print('list ' + str(i) + ' checked')
    return res

# %% [markdown]
# ## Using keywords to filter full set of abstracts

# %%
import numpy as np
import pandas as pd

# %%
#read paper indexed abstracts
abstract = pd.read_csv('/bgfs/mrfrank/datawarehouse/MAG/NEW_MAG/PaperAbstractsInvertedIndex.txt',
                       sep = '\t',
                       names = ['Paper ID', 'Indexed Abstract'],
                      dtype = {'Paper ID': np.uint32})

# %%
abstract
# Out:
#             Paper ID                                   Indexed Abstract     A  \
# 28        1963479539  {"indexlength":141,"invertedindex":{"over":[0]...  True
# 193       1963479783  {"indexlength":214,"invertedindex":{"managing"...  True
# 542       2095588949  {"indexlength":141,"invertedindex":{"education...  True
# 549       1963480270  {"indexlength":171,"invertedindex":{"abstract"...  True
# 827       2335780457  {"indexlength":133,"invertedindex":{"the":[0],...  True
# ...              ...                                                ...   ...
# 86501793  2172300558  {"indexlength":143,"invertedindex":{"with":[0]...  True
# 86502047    27485236  {"indexlength":356,"invertedindex":{"the":[0,1...  True
# 86502113  2095588424  {"indexlength":298,"invertedindex":{"the":[0,3...  True
# 86502117  1608941198  {"indexlength":607,"invertedindex":{"abstract\...  True
# 86502143  2419678452  {"indexlength":214,"invertedindex":{"disclosed...  True
#
#              B
# 28        True
# 193       True
# 542       True
# 549       True
# 827       True
# ...        ...
# 86501793  True
# 86502047  True
# 86502113  True
# 86502117  True
# 86502143  True
#
# [1166857 rows x 4 columns]

# %%
keyA = [
    'ethic',
    'ethos',
    'moral',
    'value',
    'code',
    'principle',
    'bias', 
    'rational', 
    'honest', 
    'integrity',
    'philosoph',
    'logic'
]
keyB = [
    'comput',
    'artificial',
    'intelligen',
    'machine learning',
    'algorithm',
    'tech',
    'robot',
    'cyber',
    'information',
    'system',
    '"ai"',
    '\(ai\)'
]
keyC = [
    'social',
    'society',
    'responsib',
    'law',
    'legal',
    'priva', 
    'meaningful',
    'impartial',
    'safe',
    'trust',
    'fair',
    'just',
    'govern',
    'regulat',
    'rule'
]

# %%
abl = np.array_split(abstract, 10)

# %%
resA = []
i = 1
for a in abl:
    resA.append(listAFilter(a))
    print('dataframe ' + str(i) + ' read')
    i += 1
# Out:
# list A checked
# dataframe 1 read
# list A checked
# dataframe 2 read
# list A checked
# dataframe 3 read
# list A checked
# dataframe 4 read
# list A checked
# dataframe 5 read
# list A checked
# dataframe 6 read
# list A checked
# dataframe 7 read
# list A checked
# dataframe 8 read
# list A checked
# dataframe 9 read
# list A checked
# dataframe 10 read

# %%
filtA = pd.concat(resA)

# %%
filtA
# Out:
#             Paper ID                                   Indexed Abstract      A
# 0         2514067917  {"indexlength":138,"invertedindex":{"a":[0],"s...  False
# 1         2196491992  {"indexlength":7,"invertedindex":{"早期発見と治療成績の向...  False
# 2         1963479517  {"indexlength":141,"invertedindex":{"this":[0]...  False
# 3         1963479518  {"indexlength":147,"invertedindex":{"the":[0,7...  False
# 4         1963479519  {"indexlength":242,"invertedindex":{"cleavage"...  False
# ...              ...                                                ...    ...
# 86502167  2172300924  {"indexlength":148,"invertedindex":{"curing":[...  False
# 86502168  2394483106  {"indexlength":161,"invertedindex":{"objective...  False
# 86502169  2781472873  {"indexlength":197,"invertedindex":{"an":[0],"...  False
# 86502170   350727719  {"indexlength":160,"invertedindex":{"the":[0],...  False
# 86502171  2408756851  {"indexlength":202,"invertedindex":{"the":[0,8...  False
#
# [86502172 rows x 3 columns]

# %% [markdown]
# We retain just under a quarter of the full set of abstracts after the first list.

# %%
Apass = filtA[filtA['A']]

# %%
Apass
# Out:
#             Paper ID                                   Indexed Abstract     A
# 10        1819117828  {"indexlength":207,"invertedindex":{"in":[0,45...  True
# 18        2347208820  {"indexlength":82,"invertedindex":{"agricultur...  True
# 22        2347208823  {"indexlength":39,"invertedindex":{"susceptibi...  True
# 25        2342385460  {"indexlength":312,"invertedindex":{"objective...  True
# 27        2095588557  {"indexlength":181,"invertedindex":{"the":[0,3...  True
# ...              ...                                                ...   ...
# 86502133  2095588458  {"indexlength":91,"invertedindex":{"summary":[...  True
# 86502135  2273582401  {"indexlength":149,"invertedindex":{"neutrophi...  True
# 86502137  2172300891  {"indexlength":181,"invertedindex":{"filtering...  True
# 86502143  2419678452  {"indexlength":214,"invertedindex":{"disclosed...  True
# 86502165  2288199931  {"indexlength":83,"invertedindex":{"mas":[0],"...  True
#
# [19793903 rows x 3 columns]

# %%
Alist = np.array_split(Apass, 10)

# %%
resB = []
i = 1
for a in Alist:
    resB.append(listBFilter(a))
    print('dataframe ' + str(i) + ' read')
    i += 1
# Out:
# list B checked
# dataframe 1 read
# list B checked
# dataframe 2 read
# list B checked
# dataframe 3 read
# list B checked
# dataframe 4 read
# list B checked
# dataframe 5 read
# list B checked
# dataframe 6 read
# list B checked
# dataframe 7 read
# list B checked
# dataframe 8 read
# list B checked
# dataframe 9 read
# list B checked
# dataframe 10 read

# %%
filtB = pd.concat(resB)
filtB
# Out:
#             Paper ID                                   Indexed Abstract     A  \
# 10        1819117828  {"indexlength":207,"invertedindex":{"in":[0,45...  True
# 18        2347208820  {"indexlength":82,"invertedindex":{"agricultur...  True
# 22        2347208823  {"indexlength":39,"invertedindex":{"susceptibi...  True
# 25        2342385460  {"indexlength":312,"invertedindex":{"objective...  True
# 27        2095588557  {"indexlength":181,"invertedindex":{"the":[0,3...  True
# ...              ...                                                ...   ...
# 86502133  2095588458  {"indexlength":91,"invertedindex":{"summary":[...  True
# 86502135  2273582401  {"indexlength":149,"invertedindex":{"neutrophi...  True
# 86502137  2172300891  {"indexlength":181,"invertedindex":{"filtering...  True
# 86502143  2419678452  {"indexlength":214,"invertedindex":{"disclosed...  True
# 86502165  2288199931  {"indexlength":83,"invertedindex":{"mas":[0],"...  True
#
#               B
# 10         True
# 18        False
# 22        False
# 25        False
# 27         True
# ...         ...
# 86502133  False
# 86502135  False
# 86502137   True
# 86502143   True
# 86502165  False
#
# [19793903 rows x 4 columns]

# %%
Bpass = filtB[filtB['B']]

# %%
Bpass
# Out:
#             Paper ID                                   Indexed Abstract     A  \
# 10        1819117828  {"indexlength":207,"invertedindex":{"in":[0,45...  True
# 27        2095588557  {"indexlength":181,"invertedindex":{"the":[0,3...  True
# 28        1963479539  {"indexlength":141,"invertedindex":{"over":[0]...  True
# 42        2095588566  {"indexlength":151,"invertedindex":{"based":[0...  True
# 48        2252279066  {"indexlength":542,"invertedindex":{"today":[0...  True
# ...              ...                                                ...   ...
# 86502113  2095588424  {"indexlength":298,"invertedindex":{"the":[0,3...  True
# 86502122  2250173118  {"indexlength":44,"invertedindex":{"ve":[0],"s...  True
# 86502132   129570569  {"indexlength":55,"invertedindex":{"in":[0],"t...  True
# 86502137  2172300891  {"indexlength":181,"invertedindex":{"filtering...  True
# 86502143  2419678452  {"indexlength":214,"invertedindex":{"disclosed...  True
#
#              B
# 10        True
# 27        True
# 28        True
# 42        True
# 48        True
# ...        ...
# 86502113  True
# 86502122  True
# 86502132  True
# 86502137  True
# 86502143  True
#
# [8125922 rows x 4 columns]

# %%
Blist = np.array_split(Bpass, 10)

# %%
resC = []
i = 1
for a in Blist:
    resC.append(listCFilter(a))
    print('dataframe ' + str(i) + ' read')
    i += 1
# Out:
# list C checked
# dataframe 1 read
# list C checked
# dataframe 2 read
# list C checked
# dataframe 3 read
# list C checked
# dataframe 4 read
# list C checked
# dataframe 5 read
# list C checked
# dataframe 6 read
# list C checked
# dataframe 7 read
# list C checked
# dataframe 8 read
# list C checked
# dataframe 9 read
# list C checked
# dataframe 10 read

# %%
absfC = pd.concat(resC)
absfC
# Out:
#             Paper ID                                   Indexed Abstract     A  \
# 10        1819117828  {"indexlength":207,"invertedindex":{"in":[0,45...  True
# 27        2095588557  {"indexlength":181,"invertedindex":{"the":[0,3...  True
# 28        1963479539  {"indexlength":141,"invertedindex":{"over":[0]...  True
# 42        2095588566  {"indexlength":151,"invertedindex":{"based":[0...  True
# 48        2252279066  {"indexlength":542,"invertedindex":{"today":[0...  True
# ...              ...                                                ...   ...
# 86502113  2095588424  {"indexlength":298,"invertedindex":{"the":[0,3...  True
# 86502122  2250173118  {"indexlength":44,"invertedindex":{"ve":[0],"s...  True
# 86502132   129570569  {"indexlength":55,"invertedindex":{"in":[0],"t...  True
# 86502137  2172300891  {"indexlength":181,"invertedindex":{"filtering...  True
# 86502143  2419678452  {"indexlength":214,"invertedindex":{"disclosed...  True
#
#              B      C
# 10        True  False
# 27        True  False
# 28        True  False
# 42        True   True
# 48        True   True
# ...        ...    ...
# 86502113  True  False
# 86502122  True  False
# 86502132  True  False
# 86502137  True   True
# 86502143  True  False
#
# [8125922 rows x 5 columns]

# %%
Cpass = absfC[absfC['C']]
Cpass.set_index('Paper ID', inplace = True)

# %%
Cpass
# Out:
#                                              Indexed Abstract     A     B  \
# Paper ID
# 2095588566  {"indexlength":151,"invertedindex":{"based":[0...  True  True
# 2252279066  {"indexlength":542,"invertedindex":{"today":[0...  True  True
# 2505312253  {"indexlength":1508,"invertedindex":{"issn:":[...  True  True
# 2552604832  {"indexlength":240,"invertedindex":{"summary":...  True  True
# 1963480011  {"indexlength":149,"invertedindex":{"street":[...  True  True
# ...                                                       ...   ...   ...
# 2394482995  {"indexlength":199,"invertedindex":{"an":[0],"...  True  True
# 2240119898  {"indexlength":605,"invertedindex":{"introduct...  True  True
# 27485236    {"indexlength":356,"invertedindex":{"the":[0,1...  True  True
# 2232604002  {"indexlength":253,"invertedindex":{"accurate"...  True  True
# 2172300891  {"indexlength":181,"invertedindex":{"filtering...  True  True
#
#                C
# Paper ID
# 2095588566  True
# 2252279066  True
# 2505312253  True
# 2552604832  True
# 1963480011  True
# ...          ...
# 2394482995  True
# 2240119898  True
# 27485236    True
# 2232604002  True
# 2172300891  True
#
# [2200482 rows x 4 columns]

# %%
Cpass.to_csv('/bgfs/mrfrank/nolan/threelistfilterAllPapers.csv')
